# %%
threshold = [0.50,0.51,0.52,0.53,0.54,0.55,0.56,0.57,0.58,0.59,0.60,0.61,0.62,0.63,0.64,0.65,0.66,0.67,0.68,0.69,0.70]

precision_grb_58 = [0.0825192896961642,0.08749715645615692,0.0882561811204205,0.08872375673858653,0.09668691658023411,0.0988438870040822,0.09973583103241673,0.10071578184376449,0.1057751229844142,0.10656944242566868,0.11007518214793001,0.11434046835449538,0.11866563674918139,0.11882769078046679,0.11934780348104201,0.15497395964227856,0.1701687758871921,0.18105439382430905,0.1869499387560677,0.23213300578552534,0.27337829781426654]

recall_grb_58 = [0.4671654892781006,0.4644716613951242,0.46292038809699637,0.4621586850404306,0.454611322437264,0.4500643267520331,0.44223829229890343,0.4388384957293539,0.43211785961441107,0.42906640285731534,0.4225594151606775,0.41373016204768076,0.4088441156116615,0.40473835035553885,0.39446464815356674,0.3723241696740004,0.34442447296186374,0.32548872075687274,0.3062371404552569,0.22865489742553655,0.17677084349324454]

F1_Score_grb_58 = [0.14026280450306855,0.14725451261810257,0.14824862992355536,0.14886825803971027,0.15945984912723993,0.16208942166717824,0.16276424167883904,0.16383138467300482,0.16994949264309658,0.17073303707646403,0.17465371129538035,0.17916580766813325,0.18394256065630635,0.18371750558417477,0.18325164817737635,0.21885361482211524,0.22779269289132717,0.23267975158249124,0.23216753668606238,0.2303808249178732,0.2147080061377381]

# %%
#matplotlib inline

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.figure(figsize = (30,10))
plt.subplot(1, 3, 1)
plt.title('Precision', fontsize = 25, color = '#9b596B')
plt.xlabel('Threshold', fontsize = 25)
plt.plot(threshold, precision_grb_58, color = '#9b596B')
plt.subplot(1, 3, 2)
plt.title('Recall', fontsize = 25, color = '#99CC01')
plt.xlabel('Threshold', fontsize = 25,)
plt.plot(threshold, recall_grb_58, color = '#99CC01')
plt.subplot(1, 3, 3)
plt.title('F1 Score', fontsize = 25, color = '#0D8ECF')
plt.xlabel('Threshold', fontsize = 25,)
plt.plot(threshold, F1_Score_grb_58, color = '#0D8ECF')
plt.show()
# Out:
# //anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
precision_grb_558 = [0.08251840961894386,0.08749799856334033,0.08825539963305871,0.08872296564711253,0.09668605702127407,0.0988414672707874,0.09971067666020232,0.10071631099835845,0.10577373454418125,0.10656757982070696,0.11007466072381339,0.11434336640322852,0.11866554509474048,0.11882613782326616,0.11934828887187089,0.15497986634267233,0.1701748307109109,0.1810441696523826,0.18693925452210666,0.23211566655824106,0.27335592928233926]
recall_grb_558 = [0.4671654892781006,0.4644716613951242,0.46292038809699637,0.4621586850404306,0.454611322437264,0.4500643267520331,0.44178312827729704,0.4388431402601866,0.4321225041452438,0.4290524692648172,0.4225640596915103,0.41373480657851347,0.4088487601424942,0.40474299488637155,0.39448787080773035,0.3723520368589967,0.34444305108519463,0.32551658794186905,0.3062882302944168,0.2286874091413656,0.17680335520907356]
F1_Score_grb_558 = [0.1402615331518196,0.14725570519408998,0.14824752741062128,0.1488671444589978,0.1594586801296118,0.16208616817974636,0.1626999025877117,0.16383240842448765,0.16994805970530938,0.17072954361478382,0.1746534516617619,0.17916980099842716,0.18394292060686038,0.18371612797136236,0.18325472614059538,0.21886431886431887,0.22780218092458915,0.23267842796151575,0.2321739773339389,0.23038878516917233,0.2147250856683542]

# %%
plt.figure(figsize = (30,10))
plt.subplot(1, 3, 1)
plt.title('Precision', fontsize = 25, color = '#9b596B')
plt.xlabel('Threshold', fontsize = 25)
plt.plot(threshold, precision_grb_558, color = '#9b596B')
plt.subplot(1, 3, 2)
plt.title('Recall', fontsize = 25, color = '#99CC01')
plt.xlabel('Threshold', fontsize = 25,)
plt.plot(threshold, recall_grb_558, color = '#99CC01')
plt.subplot(1, 3, 3)
plt.title('F1 Score', fontsize = 25, color = '#0D8ECF')
plt.xlabel('Threshold', fontsize = 25,)
plt.plot(threshold, F1_Score_grb_558, color = '#0D8ECF')
plt.show()

# %%
precision_rf_558 = [0.11442076143020223,0.12370757079666697,0.12506750731590913,0.17651171326532394,0.1938600820506493,0.20771823272305992,0.24743524792603383,0.24554785209352908,0.2471515432483997,0.2510097410311238,0.2563711194090872,0.26813901497188536,0.26458999330904764,0.27011494252873564,0.26530057614958147,0.26555323590814195,0.2599975390673065,0.2583738906384197,0.26154122507634275,0.2870946246112839,0.28507795100222716]
recall_rf_558 = [0.2551101450486979,0.20899924294147426,0.1850009521288207,0.1407153506388552,0.11675886060369611,0.10992211121793533,0.07258937238454857,0.06711347053277412,0.06437784187230326,0.04906946824766496,0.04368645701254488,0.03676610607179516,0.03305977046728625,0.027941497489631085,0.02266995499449623,0.020677451267260238,0.019627787299065984,0.016766756306111737,0.013524873784874622,0.012006112202575856,0.011295498985170013]
F1_Score_rf_558 = [0.157983521991052,0.1554208544883086,0.1492419317673022,0.15659387517767154,0.1457405147500022,0.14376528117359413,0.11224867221362367,0.10541482008352938,0.10214820000736947,0.08209108886272956,0.07465197860283497,0.06466554207222183,0.05877568546172933,0.050644206769116795,0.04177060824543762,0.03836740321969044,0.03650010148513782,0.031490018710828294,0.025719723901590264,0.023048356968672957,0.021730001161554338]

# %%
plt.figure(figsize = (30,10))
plt.subplot(1, 3, 1)
plt.title('Precision', fontsize = 25, color = '#9b596B')
plt.xlabel('Threshold', fontsize = 25)
plt.plot(threshold, precision_rf, color = '#9b596B')
plt.subplot(1, 3, 2)
plt.title('Recall', fontsize = 25, color = '#99CC01')
plt.xlabel('Threshold', fontsize = 25,)
plt.plot(threshold, recall_rf, color = '#99CC01')
plt.subplot(1, 3, 3)
plt.title('F1 Score', fontsize = 25, color = '#0D8ECF')
plt.xlabel('Threshold', fontsize = 25,)
plt.plot(threshold, F1_Score_rf, color = '#0D8ECF')
plt.show()

# %%
precision_rf_58_100 = [0.10424652921674264, 0.10842143500274591, 0.11293320696216946, 0.11851279460278777, 0.12442807937487148, 0.12948197990598212, 0.13527053606730494, 0.14176785059615984, 0.14578812446960643, 0.14896493161461927, 0.15167612511548106, 0.15488628305755534, 0.15928808464411673, 0.16367380298678008, 0.17005096778887097, 0.1792978748385582, 0.1920953667913223, 0.20620400504295305, 0.21791382188817504, 0.23041170584567194, 0.2468325002905963]
recall_rf_58_100 = [0.299089207503704, 0.29250326278291, 0.2855643337188294, 0.27780796722819046, 0.269796151541752, 0.2609761874904207, 0.2510647586934006, 0.24066565415894514, 0.23059166678277992, 0.2216184332139689, 0.21350908238004337, 0.20594314165354588, 0.19886023213365103, 0.1916008304421129, 0.1845597216997125, 0.17731425360067252, 0.1703428128207629, 0.1633249267325261, 0.15580078678352305, 0.14758925627127775, 0.13807725712587143]
F1_Score_rf_58_100 = [0.1546057488580912, 0.1582023939610887, 0.1618564367838786, 0.16614723087948535, 0.17031026672823624, 0.17308749713138044, 0.1758144542144438, 0.17842920182571673, 0.17863619354653004, 0.17816976087703315, 0.17735784269281446, 0.17680247533832547, 0.17688797631908912, 0.17653968858523894, 0.17700853482529447, 0.1783005473668479, 0.18056632523699453, 0.18227668320193238, 0.18169557257531604, 0.1799270145319786, 0.1770906242460886]

# %%
len(F1_Score_rf_58)
# Out:
# 21

# %%
plt.figure(figsize = (30,10))

plt.subplot(1, 3, 1)
plt.title('Precision', fontsize = 25, color = '#9b596B')
plt.xlabel('Threshold', fontsize = 25)
plt.plot(threshold, precision_rf_58, color = '#9b596B', label = 'rf_58', linestyle = '--')
plt.plot(threshold, precision_rf_558, color = '#FA4D3D', label = 'rf_558')
plt.legend(shadow=True, fancybox=True)

plt.subplot(1, 3, 2)
plt.title('Recall', fontsize = 25, color = '#99CC01')
plt.xlabel('Threshold', fontsize = 25)
plt.plot(threshold, recall_rf_58, color = '#99CC01', label = 'rf_58', linestyle = '--')
plt.plot(threshold, recall_rf_558, color = '#00DD00', label = 'rf_558')
plt.legend(shadow=True, fancybox=True)

plt.subplot(1, 3, 3)
plt.title('F1 Score', fontsize = 25, color = '#0D8ECF')
plt.xlabel('Threshold', fontsize = 25)
plt.plot(threshold, F1_Score_rf_58, color = '#0D8ECF', label = 'rf_58', linestyle = '--')
plt.plot(threshold, F1_Score_rf_558, color = '#0000FE', label = 'rf_558')

plt.legend(shadow=True, fancybox=True)
plt.show()

# %%
# index_58_100 = F1_Score_rf_58.index(max(F1_Score_rf_58))
# print(F1_Score_rf_58[index_58_100])
# print(threshold[index_58_100])
# print(precision_rf_58[index_58_100])
# print(recall_rf_58[index_58_100])

# index_558 = F1_Score_rf_558.index(max(F1_Score_rf_558))
# print(F1_Score_rf_558[index_558])
# print(threshold[index_558])
# print(precision_rf_558[index_558])
# print(recall_rf_558[index_558])

index_58_10 = F1_Score_rf_58_10.index(max(F1_Score_rf_58_10))
print(F1_Score_rf_58_10[index_58_10])
print(threshold[index_58_10])
print(precision_rf_58_10[index_58_10])
print(recall_rf_58_10[index_58_10])
# Out:
# 0.175944029456
# 0.67
# 0.219745510961
# 0.146702150882

# %%
precision_rf_58_10 =  [0.09790660521990543, 0.09832190377826716, 0.09876264530392755, 0.09937573490485767, 0.10459290656921187, 0.10482051943030225, 0.11599479158661183, 0.11651458197443364, 0.12885864637262645, 0.1317126259933761, 0.13300966702470463, 0.15274304118610216, 0.15817594331499052, 0.15803597300554756, 0.17837052269424314, 0.18681858947345673, 0.20269685914575097, 0.21974551096083875, 0.2278871860526415, 0.23092585658116457, 0.25683971575207265]
recall_rf_58_10 = [0.29631177806573866, 0.29093341136145134, 0.28652575160120203, 0.2641716247033306, 0.25947135950062006, 0.2568471995801344, 0.24535198576915754, 0.24142735721551087, 0.22507396415351102, 0.2214651636964892, 0.21567807827892266, 0.19713711119471267, 0.17916277687209425, 0.17478298429684125, 0.1675932505677939, 0.1606032316645534, 0.15457463064368554, 0.14670215088222863, 0.14054350299804466, 0.13748275717928354, 0.12086462585981878]
F1_Score_rf_58_10 = [0.14718177288079287, 0.14697359684091235, 0.14689277644039023, 0.144422720463144, 0.14908831319594093, 0.14888172462763416, 0.15751933731311238, 0.15717525399129173, 0.16388840978189922, 0.1651845564928204, 0.1645441789267795, 0.17212363541987705, 0.16801653378515227, 0.16598813488300287, 0.17281402282060798, 0.1727218463490351, 0.1753948637410474, 0.17594402945583573, 0.17386208243797616, 0.17235386079984633, 0.16437637977809852]

# %%
plt.figure(figsize = (30,10))

plt.subplot(1, 3, 1)
plt.title('Precision', fontsize = 25, color = '#9b596B')
plt.xlabel('Threshold', fontsize = 25)
plt.plot(threshold, precision_rf_58_10, color = '#9b596B', label = 'rf_58_10', linestyle = '--')
plt.plot(threshold, precision_rf_58_100, color = '#9b596B', label = 'rf_58_100', linestyle = '-.')
plt.plot(threshold, precision_rf_558, color = '#FA4D3D', label = 'rf_558')
plt.legend(shadow=True, fancybox=True)

plt.subplot(1, 3, 2)
plt.title('Recall', fontsize = 25, color = '#99CC01')
plt.xlabel('Threshold', fontsize = 25)
plt.plot(threshold, recall_rf_58_10, color = '#99CC01', label = 'rf_58_10', linestyle = '--')
plt.plot(threshold, recall_rf_58_100, color = '#9b596B', label = 'rf_58_100', linestyle = '-.')
plt.plot(threshold, recall_rf_558, color = '#00DD00', label = 'rf_558')
plt.legend(shadow=True, fancybox=True)

plt.subplot(1, 3, 3)
plt.title('F1 Score', fontsize = 25, color = '#0D8ECF')
plt.xlabel('Threshold', fontsize = 25)
plt.plot(threshold, F1_Score_rf_58_10, color = '#0D8ECF', label = 'rf_58_10', linestyle = '--')
plt.plot(threshold, F1_Score_rf_58_100, color = '#9b596B', label = 'rf_58_100', linestyle = '-.')
plt.plot(threshold, F1_Score_rf_558, color = '#0000FE', label = 'rf_558')

plt.legend(shadow=True, fancybox=True)
plt.show()
